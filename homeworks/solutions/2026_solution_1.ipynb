# %% [markdown]
# # Task 1

# %%
import numpy as np
import pandas as pd

pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# # Task 2

# %%
from pathlib import Path

# %%
DATA_DIR = Path.cwd().parent.parent / 'datasets'

car_fuel = pd.read_csv(DATA_DIR / 'car_fuel_efficiency_2026.csv')
car_fuel.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
car_fuel.shape[0]
# Out:
# 10000

# %% [markdown]
# # Task 3

# %%
fuel_types = car_fuel['fuel_type'].value_counts()
fuel_types
# Out:
# fuel_type
# Gasoline    6913
# Diesel      2053
# Hybrid      1034
# Name: count, dtype: int64

# %%
fuel_types.nunique()
# Out:
# 3

# %% [markdown]
# # Task 4

# %%
missing_columns = car_fuel.isnull().sum()
missing_columns
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
(missing_columns > 0).sum()
# Out:
# np.int64(2)

# %% [markdown]
# # Task 5

# %%
asia_fuel = car_fuel[car_fuel['origin'] == 'Asia']
asia_fuel.head(3)
# Out:
#    model_year origin fuel_type         drivetrain  num_doors  \
# 2        1996   Asia  Gasoline  Front-wheel drive          5
# 6        1992   Asia  Gasoline  Front-wheel drive          2
# 8        1997   Asia  Gasoline   Rear-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                 2320              6       267.0            4240
# 6                 2270              6       250.0            4310
# 8                 2330              6       251.0            4230
#
#    acceleration  fuel_efficiency_mpg
# 2          17.3                 27.5
# 6          21.7                 26.8
# 8          19.5                 30.9

# %%
max_asia_fuel_eff = asia_fuel['fuel_efficiency_mpg'].max()
max_asia_fuel_eff
# Out:
# np.float64(41.2)

# %% [markdown]
# # Task 6

# %%
horsepow_med = car_fuel['horsepower'].median()
horsepow_med
# Out:
# np.float64(254.0)

# %% [markdown]
# Horsepower's null values should be filled with the median.

# %%
freq_horsepow = car_fuel['horsepower'].mode().iloc[0]
freq_horsepow
# Out:
# np.float64(252.0)

# %%
freq_horsepow_med = car_fuel['horsepower'].fillna(freq_horsepow)
freq_horsepow_med.value_counts()[:3]
# Out:
# horsepower
# 252.0    1051
# 246.0     168
# 256.0     168
# Name: count, dtype: int64

# %%
freq_horsepow_med.isnull().sum()
# Out:
# np.int64(0)

# %%
freq_horsepow_med.median()
# Out:
# np.float64(252.0)

# %% [markdown]
# horsepower is decreased

# %% [markdown]
# # Task 7

# %%
X = asia_fuel[['vehicle_weight', 'model_year']].iloc[:7]
X
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %%
XTX = X.T @ X
XTX
# Out:
#                 vehicle_weight  model_year
# vehicle_weight       131950500    60750580
# model_year            60750580    28041424

# %%
inv_XTX = np.linalg.inv()
